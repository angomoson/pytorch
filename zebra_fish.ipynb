# %% [markdown]
# <a href="https://colab.research.google.com/github/angomoson/pytorch/blob/main/zebra_fish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
# !nvidia-smi
# Out:
# Thu Oct 24 17:46:40 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/tamochou/zebra_embryo.v1i.yolov11'
# Out:
# /content/drive/MyDrive/tamochou/zebra_embryo.v1i.yolov11

# %%
# !yolo task=detect mode=train model=yolo11m.pt data= data.yaml epochs=100 imgsz=800 plots=True batch=16
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls runs/detect/train/
# Out:
# args.yaml					     labels_correlogram.jpg  weights
# events.out.tfevents.1729791441.3f07b0110a7c.15109.0  labels.jpg

# %%
from IPython.display import display, Image

# %%
Image(filename='runs/detect/train5/results.png', width=900)

# %%
Image(filename='runs/detect/train5/val_batch0_pred.jpg', width=1200)

# %%
# !yolo task=detect mode=val model=runs/detect/train5/weights/best.pt data=data.yaml
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11m summary (fused): 303 layers, 20,031,574 parameters, 0 gradients, 67.7 GFLOPs
# val: Scanning /content/drive/MyDrive/tamochou/zebra_embryo.v1i.yolov11/valid/labels.cache... 11 images, 0 backgrounds, 0 corrupt: 100% 11/11 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.22s/it]
#                    all         11        621      0.957      0.838      0.938      0.665
#                      f         11        537      0.948      0.831      0.943      0.672
#                      u         11         84      0.965      0.845      0.933      0.658
# Speed: 0.3ms preprocess, 23.8ms inference, 0.0ms loss, 65.1ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model=runs/detect/train5/weights/best.pt conf=0.25 source=test/images
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11m summary (fused): 303 layers, 20,031,574 parameters, 0 gradients, 67.7 GFLOPs
#
# image 1/10 /content/drive/MyDrive/tamochou/zebra_embryo.v1i.yolov11/test/images/101_jpeg.rf.ae7119b34f8a0dd5c14a5748832fca30.jpg: 800x384 35 fs, 8 us, 99.0ms
# image 2/10 /content/drive/MyDrive/tamochou/zebra_embryo.v1i.yolov11/test/images/102_jpeg.rf.f1edecfbe0e26afdedaadbeb92dbbead.jpg: 800x384 30 fs, 7 us, 29.4ms
# image 3/10 /content/drive/MyDrive/tamochou/zebra_embryo.v1i.yolov11/test/images/103_jpeg.rf.7cb15684816867f5aeade8a9d132e86c.jpg: 800x384 40 fs, 7 us, 29.4ms
# image 4/10 /content/drive/MyDrive/tamochou/zebra_embryo.v1i.yolov11/test/images/104_jpeg.rf.3c0a4fb17e7ccbe9764a46924e99deec.jpg: 800x384 36 fs, 6 us, 29.6ms
# image 5/10 /content/drive/MyDrive/tamochou/zebra_embryo.v1i.yolov11/test/images/105_jpeg.rf.5c638e9c1b8ff620b0fa53c8d595c364.jpg: 800x384 36 fs, 8 us, 29.3ms
# ...
